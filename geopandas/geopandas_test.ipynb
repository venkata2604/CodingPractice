# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon
import glob

# %matplotlib inline

# %%
files = glob.glob("/mnt/d/CodingPractice/geopandas/tl_2022_20091_edges/*.shp")
print(files)
# Out:
# ['/mnt/d/CodingPractice/geopandas/tl_2022_20091_edges/tl_2022_20091_edges.shp']

# %%
street_map = gpd.read_file(files[0])

# %%
fig, ax = plt.subplots(figsize=(15,15))
street_map.plot(ax=ax)
# Out:
# <Axes: >

# %%
# type(street_map)
street_map.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'TLID', 'TFIDL', 'TFIDR', 'MTFCC', 'FULLNAME',
#        'SMID', 'LFROMADD', 'LTOADD', 'RFROMADD', 'RTOADD', 'ZIPL', 'ZIPR',
#        'FEATCAT', 'HYDROFLG', 'RAILFLG', 'ROADFLG', 'OLFFLG', 'PASSFLG',
#        'EXTTYP', 'TTYP', 'DECKEDROAD', 'ARTPATH', 'PERSIST', 'GCSEFLG',
#        'OFFSETL', 'OFFSETR', 'TNIDF', 'TNIDT', 'geometry'],
#       dtype='object')

# %%
street_map.iloc[0]
# Out:
# STATEFP                                                      20
# COUNTYFP                                                    091
# TLID                                                   91339910
# TFIDL                                                 212553341
# TFIDR                                                 212553331
# MTFCC                                                     P0002
# FULLNAME                                                    NaN
# SMID                                                        853
# LFROMADD                                                    NaN
# LTOADD                                                      NaN
# RFROMADD                                                    NaN
# RTOADD                                                      NaN
# ZIPL                                                        NaN
# ZIPR                                                        NaN
# FEATCAT                                                     NaN
# ...

# %%
import geopandas
from geodatasets import get_path

path_to_data = get_path("nybb")
gdf = geopandas.read_file(path_to_data)

print(type(gdf))
gdf
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
# New York 
files = glob.glob("/mnt/d/CodingPractice/geopandas/tl_2022_36_place/*.shp")
print(files)
street_map = gpd.read_file(files[0])
fig, ax = plt.subplots(figsize=(15,15))
street_map.plot(ax=ax)
# Out:
# ['/mnt/d/CodingPractice/geopandas/tl_2022_36_place/tl_2022_36_place.shp']
# <Axes: >

# %%
# Kansas
files = glob.glob("/mnt/d/CodingPractice/geopandas/tl_2022_20_place/*.shp")
print(files)
street_map = gpd.read_file(files[0])
fig, ax = plt.subplots(figsize=(15,15))
street_map.plot(ax=ax)
# Out:
# ['/mnt/d/CodingPractice/geopandas/tl_2022_20_place/tl_2022_20_place.shp']
# <Axes: >
