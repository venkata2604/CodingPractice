# %% [markdown]
# # Fourier Transforms

# %% [markdown]
# ![image.png](attachment:bbdc5c86-7d57-4e75-ba05-c21f254aa328.png)

# %% [markdown]
# ## Joseph Fourier

# %% [markdown]
# Definition :
# Any Periodic Function can be written as a weighted sum of Infinite Sinusoids of Different Frequencies.

# %% [markdown]
# What is a Sinusoid?
# *

# %% [markdown]
# $$ f(x) = Asin(2(pi)ux + (phi)) $$

# %% [markdown]
# Where A : Amplitude <br>
# T: Period
# phi: Phase
# u : Freqeuncy (1/T)
